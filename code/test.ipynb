# %% [markdown]
# # Hello World
#
# <div style="display: flex; gap: 10px;">
#   <img src="https://i.redd.it/lunmi0varne31.jpg" width="250" />
#   <img src="https://img.devrant.com/devrant/rant/r_1752396_5gPJp.jpg" width="250" />
#   <img src="https://i.programmerhumor.io/2021/08/programmerhumor-io-programming-memes-python-memes-9f11021bb2dfd2f.jpg" width="300" />
# </div>

# %% [markdown]
# # Test MNE

# %%
import mne
mne.viz.set_3d_backend("pyvista")
report = mne.viz.get_3d_backend()
print(f"Active 3D backend: {report}")

# %% [markdown]
# # Test PyVista

# %%
import pyvista as pv
sphere = pv.Sphere()
sphere.plot(show_edges=True)

# %% [markdown]
# # Messaggio Segreto

# %%
messaggio_segreto = '                                                        ,--,                                          _.--,-```-.    \n  .--,-``-.                                          ,---.\'|       ,----..                           /    /      \'.  \n /   /     \'.      ,----..              ,---,.       |   | :      /   /   \\      ,---,        ,---,./  ../         ; \n/ ../        ;    /   /   \\           ,\'  .\' |       :   : |     /   .     :   .\'  .\' `\\    ,\'  .\' |\\  ``\\  .``-    \'\n\\ ``\\  .`-    \'  /   .     :        ,---.\'   |       |   \' :    .   /   ;.  \\,---.\'     \\ ,---.\'   | \\ ___\\/    \\   :\n \\___\\/   \\   : .   /   ;.  \\       |   |   .\'       ;   ; \'   .   ;   /  ` ;|   |  .`\\  ||   |   .\'       \\    :   |\n      \\   :   |.   ;   /  ` ;       :   :  |-,       \'   | |__ ;   |  ; \\ ; |:   : |  \'  |:   :  |-,       |    ;  . \n      /  /   / ;   |  ; \\ ; |       :   |  ;/|       |   | :.\'||   :  | ; | \'|   \' \'  ;  ::   |  ;/|      ;   ;   :  \n      \\  \\   \\ |   :  | ; | \'       |   :   .\'       \'   :    ;.   |  \' \' \' :\'   | ;  .  ||   :   .\'     /   :   :   \n  ___ /   :   |.   |  \' \' \' :       |   |  |-,       |   |  ./ \'   ;  \\; /  ||   | :  |  \'|   |  |-,     `---\'.  |   \n /   /\\   /   :\'   ;  \\; /  |       \'   :  ;/|       ;   : ;    \\   \\  \',  / \'   : | /  ; \'   :  ;/|      `--..`;    \n/ ,,/  \',-    . \\   \\  \',  /        |   |    \\       |   ,/      ;   :    /  |   | \'` ,/  |   |    \\    .--,_        \n\\ \'\'\\        ;   ;   :    /         |   :   .\'       \'---\'        \\   \\ .\'   ;   :  .\'    |   :   .\'    |    |`.     \n \\   \\     .\'     \\   \\ .\'          |   | ,\'                       `---`     |   ,.\'      |   | ,\'      `-- -`, ;    \n  `--`-,,-\'        `---`            `----\'                                   \'---\'        `----\'          \'---`"     \n                                                                                                                     '

print(messaggio_segreto)
